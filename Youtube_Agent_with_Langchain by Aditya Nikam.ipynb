# %%
# %pip install pytube #it is a Python library which helps to download youtube videos,Download audio and
#metadata about the youtube video
# %pip install youtube-transcript-api #It downloads the subtitles (transcript) of YouTube videos
# %pip install langchain-community #This package contains integrations built and maintained by the community.
# %pip install langchain-openai #This package connects LangChain with OpenAI models.
# %pip install yt-dlp #This installs yt-dlp, a powerful command-line tool and Python library for downloading media from YouTube and many other websites.
# Out:
# Requirement already satisfied: pytube in /usr/local/lib/python3.12/dist-packages (15.0.0)
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2026.6.17)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.3.16)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Collecting langchain<0.4.0,>=0.3.16 (from langchain-community)
#   Using cached langchain-0.3.30-py3-none-any.whl.metadata (6.4 kB)
# Collecting langchain-core<0.4.0,>=0.3.32 (from langchain-community)
#   Using cached langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.3.45)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4.0,>=0.3.16->langchain-community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<0.4.0,>=0.3.16->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain-community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.5.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.32->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.16->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.16->langchain-community) (2.46.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Using cached langchain-0.3.30-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.86-py3-none-any.whl (461 kB)
# Installing collected packages: langchain-core, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.2
#     Uninstalling langchain-core-1.5.2:
#       Successfully uninstalled langchain-core-1.5.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.14
#     Uninstalling langchain-1.3.14:
#       Successfully uninstalled langchain-1.3.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 4.3.2 requires langchain-core<2.0.0,>=1.5.1, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.86 which is incompatible.
# langgraph 1.2.9 requires langchain-core<2,>=1.4.7, but you have langchain-core 0.3.86 which is incompatible.
# Successfully installed langchain-0.3.30 langchain-core-0.3.86
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.12/dist-packages (0.3.14)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.53 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.3.86)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (4.16.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (2.13.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.53->langchain-openai) (0.17.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain-openai) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.53->langchain-openai) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.53->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.53->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.53->langchain-openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.53->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.53->langchain-openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.53->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1,>=0.7->langchain-openai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (2026.7.4)

# %%
# %pip install -U google-genai
# %pip install -U langchain-google-genai
# %pip install -U langchain
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (2.14.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.56.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (49.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.12/dist-packages (4.3.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.14.0)
# Collecting langchain-core<2.0.0,>=1.5.1 (from langchain-google-genai)
#   Using cached langchain_core-1.5.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.56.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.3.45)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (49.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Using cached langchain_core-1.5.2-py3-none-any.whl (561 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.86
#     Uninstalling langchain-core-0.3.86:
#       Successfully uninstalled langchain-core-0.3.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.14 requires langchain-core<1.0.0,>=0.3.53, but you have langchain-core 1.5.2 which is incompatible.
# langchain 0.3.30 requires langchain-core<1.0.0,>=0.3.85, but you have langchain-core 1.5.2 which is incompatible.
# langchain-community 0.3.16 requires langchain-core<0.4.0,>=0.3.32, but you have langchain-core 1.5.2 which is incompatible.
# Successfully installed langchain-core-1.5.2
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.30)
# Collecting langchain
#   Using cached langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.5.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.3.45)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.5.0)
# Using cached langchain-1.3.14-py3-none-any.whl (139 kB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.30
#     Uninstalling langchain-0.3.30:
#       Successfully uninstalled langchain-0.3.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.16 requires langchain<0.4.0,>=0.3.16, but you have langchain 1.3.14 which is incompatible.
# langchain-community 0.3.16 requires langchain-core<0.4.0,>=0.3.32, but you have langchain-core 1.5.2 which is incompatible.
# Successfully installed langchain-1.3.14

# %%
import re
from pytube import YouTube
from langchain_core.tools import tool #importing tool from langchain tools module
from IPython.display import display, JSON
import yt_dlp
from typing import List, Dict
from langchain_core.messages import HumanMessage
from langchain_core.messages import ToolMessage
import json

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# Suppress pytube errors
import logging
pytube_logger = logging.getLogger('pytube')
pytube_logger.setLevel(logging.ERROR)

# Suppress yt-dlp warnings
yt_dpl_logger = logging.getLogger('yt_dlp')
yt_dpl_logger.setLevel(logging.ERROR)

# %%
import os

os.environ["GOOGLE_API_KEY"] = "your_api_key"

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

models = client.models.list()

for m in models:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-3.5-live-translate-preview

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

llm = ChatGoogleGenerativeAI(
    model="gemini-flash-latest",
    google_api_key=os.environ["GOOGLE_API_KEY"],
    temperature=0
)

# %%
@tool
def extract_video_id(url: str) -> str:
    """
    Extracts the 11-character YouTube video ID from a URL.

    Args:
        url (str): A YouTube URL containing a video ID.

    Returns:
        str: Extracted video ID or error message if parsing fails.
    """

    # Regex pattern to match video IDs
    pattern = r'(?:v=|be/|embed/)([a-zA-Z0-9_-]{11})'
    match = re.search(pattern, url)
    return match.group(1) if match else "Error: Invalid YouTube URL"

# %%
print(extract_video_id.name)
print("----------------------------")
print(extract_video_id.description)
print("----------------------------")
print(extract_video_id.func)
# Out:
# extract_video_id
# ----------------------------
# Extracts the 11-character YouTube video ID from a URL.
#
# Args:
#     url (str): A YouTube URL containing a video ID.
#
# Returns:
#     str: Extracted video ID or error message if parsing fails.
# ----------------------------
# <function extract_video_id at 0x7baed0767600>

# %%
extract_video_id.run("https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6")
# Out:
# '8x6vXibEVKE'

# %%
extract_video_id
# Out:
# StructuredTool(name='extract_video_id', description='Extracts the 11-character YouTube video ID from a URL.\n\nArgs:\n    url (str): A YouTube URL containing a video ID.\n\nReturns:\n    str: Extracted video ID or error message if parsing fails.', args_schema=<class 'langchain_core.utils.pydantic.extract_video_id'>, func=<function extract_video_id at 0x7baed0767600>)

# %%
tools = []
tools.append(extract_video_id)

# %%
from youtube_transcript_api import YouTubeTranscriptApi


@tool
def fetch_transcript(video_id: str, language: str = "en") -> str:
    """
    Fetches the transcript of a YouTube video.

    Args:
        video_id (str): The YouTube video ID (e.g., "dQw4w9WgXcQ").
        language (str): Language code for the transcript (e.g., "en", "es").

    Returns:
        str: The transcript text or an error message.
    """

    try:
        ytt_api = YouTubeTranscriptApi()
        transcript = ytt_api.fetch(video_id, languages=[language])
        return " ".join([snippet.text for snippet in transcript.snippets])
    except Exception as e:
        return f"Error: {str(e)}"

# %%
fetch_transcript.run("8x6vXibEVKE")
# Out:
# 'Hello and welcome you all, to a new video from the capital and the largest city of France, Paris. What an iconic city this is! What marvelous architecture it has! Oh man! Such a crowd. Just look at how long this line is. These are all standing in the queue. And then there are some people like this, I was making a video, and he cut in line. So many people; everybody is clicking pictures. They are all saying hello from the cruise. I have had a love-hate relationship with French-speaking cities and countries. You can do picnic here and take a breather in peace. This feels like I am now somewhere in West Africa. Oh man! Move aside, please! Wow, this car is so fascinating. I am in the middle of the road right now; let\'s run! If you want to visit Paris in the coming days, or you want to know what the city has to offer, or you want to compare Paris with Montreal, then this is the only video that you need to watch. And if you watch this entire video of Paris today. Then apart from this, you don\'t need to watch any other video on the city of Paris. You might know that the sole official and predominant language in this city and the country of France is, of course, French. And that makes Paris the largest primarily French-speaking city in the world. You might also know that before coming to Paris, I was in Montreal. Which happens to be in the Quebec province of Canada. Which is a French-speaking region, and Montreal is considered to be the most European city in North America. At the same time, we can also call Montreal the second-largest primarily French-speaking city in the world. And after spending a few days in Montreal, I decided that I want to compare the two largest French-speaking cities. And instead of exploring the Quebec province, or the rest of Canada. After Montreal, I took a direct flight to Paris. So that I can compare these two cities. First of all, let me give you a disclaimer that Paris has so much to offer, that it is impossible to cover everything in just one video. What you have to see and what you are more interested in, that is very subjective. And Paris is full of experiences from all over the world. The city has a lot of art, culture, architecture, history, cathedrals, parks, fashion, bistros, cafes, gastronomy, restaurants and whatnot. I myself have come to this city 7-8 times, and stayed here for long periods of time. But to date, I have not seen all the landmarks of this city. And because we are going to cover maximum things in one video, then the time will be limited. That\'s why we are not going to talk about a lot of things. Like the history of Paris, or France as a country, the Kingdom of France. French Revolution, Celtic tribes, Roman Empire, or how such a historic city, more than 2000 years old, Paris was settled. Not talking about all these things, this will be a very touristic video. We are going to explore the most popular landmarks of Paris. Like churches, streets, neighborhoods, gardens, markets, not museums. Apart from this, the transportation, cafes, restaurants, boulangeries, patisseries, bakeries, etc. And all these experiences are going to be biased a little, as per my personal likings and first-hand experience. Before we start today\'s video, I have a tip for you if you are thinking of coming to Paris, then don\'t try to cover everything in just one trip. Like I said, there are so many things in this city. Split the things you want to do. We will cover the essentials in this video. And if we can\'t go to any place, then in this video, I will recommend everything to you. So if you come here, then where else can you go? Wow, my man, great dedication! Very important information about Paris. Paris is distributed in 20 arrondissements. Which means the official administrative districts, or call them neighborhoods. And these 20 arrondissements have numbers. The lower the number, the more central it is. And the first arrondissement is next to the Louvre Museum. But more important than the number is  ...

# %%
tools.append(fetch_transcript)

# %%
from pytube import Search
from langchain.tools import tool
from typing import List, Dict

@tool
def search_youtube(query: str) -> List[Dict[str, str]]:
    """
    Search YouTube for videos matching the query.

    Args:
        query (str): The search term to look for on YouTube

    Returns:
        List of dictionaries containing video titles and IDs in format:
        [{'title': 'Video Title', 'video_id': 'abc123'}, ...]
        Returns error message if search fails
    """
    try:
        s = Search(query)
        return [
            {
                "title": yt.title,
                "video_id": yt.video_id,
                "url": f"https://youtu.be/{yt.video_id}"
            }
            for yt in s.results
        ]
    except Exception as e:
        return f"Error: {str(e)}"

# %%
search_out=search_youtube.run("yatri doctor Australia")
display(JSON(search_out))

# %%
tools.append(search_youtube)

# %%
@tool
def get_full_metadata(url: str) -> dict:
    """Extract metadata given a YouTube URL, including title, views, duration, channel, likes, comments, and chapters."""
    with yt_dlp.YoutubeDL({'quiet': True, 'logger': yt_dpl_logger}) as ydl:
        info = ydl.extract_info(url, download=False)
        return {
            'title': info.get('title'),
            'views': info.get('view_count'),
            'duration': info.get('duration'),
            'channel': info.get('uploader'),
            'likes': info.get('like_count'),
            'comments': info.get('comment_count'),
            'chapters': info.get('chapters', [])
        }

# %%
meta_data=get_full_metadata.run("https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6")
display(JSON(meta_data))

# %%
tools.append(get_full_metadata)

# %%
@tool
def get_thumbnails(url: str) -> List[Dict]:
    """
    Get available thumbnails for a YouTube video using its URL.

    Args:
        url (str): YouTube video URL (any format)

    Returns:
        List of dictionaries with thumbnail URLs and resolutions in YouTube's native order
    """

    try:
        with yt_dlp.YoutubeDL({'quiet': True, 'logger': yt_dpl_logger}) as ydl:
            info = ydl.extract_info(url, download=False)

            thumbnails = []
            for t in info.get('thumbnails', []):
                if 'url' in t:
                    thumbnails.append({
                        "url": t['url'],
                        "width": t.get('width'),
                        "height": t.get('height'),
                        "resolution": f"{t.get('width', '')}x{t.get('height', '')}".strip('x')
                    })

            return thumbnails

    except Exception as e:
        return [{"error": f"Failed to get thumbnails: {str(e)}"}]

# %%
thumbnails=get_thumbnails.run("https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6")

display(JSON(thumbnails))

# %%
tools.append(get_thumbnails)

# %%
llm_with_tools = llm.bind_tools(tools)

# %%
for tool in tools:
    schema = {
   "name": tool.name,
   "description": tool.description,
   "parameters": tool.args_schema.schema() if tool.args_schema else {},
   "return": tool.return_type if hasattr(tool, "return_type") else None}
    display(JSON(schema))

# %%
query = "I want to summarize youtube video: https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6 in english"
print(query)
# Out:
# I want to summarize youtube video: https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6 in english

# %%
messages = [HumanMessage(content = query)]
print(messages)
# Out:
# [HumanMessage(content='I want to summarize youtube video: https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6 in english', additional_kwargs={}, response_metadata={})]

# %%
response_1 = llm_with_tools.invoke(messages)
response_1
# Out:
# AIMessage(content=[], additional_kwargs={'function_call': {'name': 'extract_video_id', 'arguments': '{"url": "https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6"}'}, '__gemini_function_call_thought_signatures__': {'2bQQzbRQ': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fa9c1-1bcc-7603-bcc9-b67f0a524e53-0', tool_calls=[{'name': 'extract_video_id', 'args': {'url': 'https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6'}, 'id': '2bQQzbRQ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 508, 'output_tokens': 154, 'total_tokens': 662, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 106}})

# %%
messages.append(response_1)

# %%
tool_mapping = {
    "get_thumbnails" : get_thumbnails,
    "extract_video_id": extract_video_id,
    "fetch_transcript": fetch_transcript,
    "search_youtube": search_youtube,
    "get_full_metadata": get_full_metadata
}

# %%
tool_calls_1 = response_1.tool_calls
display(JSON(tool_calls_1))

# %%
tool_name=tool_calls_1[0]['name']
print(tool_name)
# Out:
# extract_video_id

# %%
tool_call_id =tool_calls_1[0]['id']
print(tool_call_id)
# Out:
# 2bQQzbRQ

# %%
args=tool_calls_1[0]['args']
print(args)
# Out:
# {'url': 'https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6'}

# %%
my_tool=tool_mapping[tool_calls_1[0]['name']]

# %%
video_id =my_tool.invoke(tool_calls_1[0]['args'])
video_id
# Out:
# '8x6vXibEVKE'

# %%
messages.append(ToolMessage(content = video_id, tool_call_id = tool_calls_1[0]['id']))

# %%
response_2 = llm_with_tools.invoke(messages)
response_2
# Out:
# AIMessage(content=[], additional_kwargs={'function_call': {'name': 'fetch_transcript', 'arguments': '{"language": "en", "video_id": "8x6vXibEVKE"}'}, '__gemini_function_call_thought_signatures__': {'4jcYUEOX': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fa9c1-20b8-72d3-9eb9-d339587188f0-0', tool_calls=[{'name': 'get_full_metadata', 'args': {'url': 'https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6'}, 'id': '4jcYUEOX', 'type': 'tool_call'}, {'name': 'fetch_transcript', 'args': {'language': 'en', 'video_id': '8x6vXibEVKE'}, 'id': '4O8BcB7h', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 685, 'output_tokens': 133, 'total_tokens': 818, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 54}})

# %%
messages.append(response_2)

# %%
tool_calls_2 = response_2.tool_calls
tool_calls_2
# Out:
# [{'name': 'get_full_metadata',
#   'args': {'url': 'https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6'},
#   'id': '4jcYUEOX',
#   'type': 'tool_call'},
#  {'name': 'fetch_transcript',
#   'args': {'language': 'en', 'video_id': '8x6vXibEVKE'},
#   'id': '4O8BcB7h',
#   'type': 'tool_call'}]

# %%
print(tool_calls_2)
print(type(tool_calls_2))
print(len(tool_calls_2))
# Out:
# [{'name': 'get_full_metadata', 'args': {'url': 'https://youtu.be/8x6vXibEVKE?si=Ayqg37GFLS34k-y6'}, 'id': '4jcYUEOX', 'type': 'tool_call'}, {'name': 'fetch_transcript', 'args': {'language': 'en', 'video_id': '8x6vXibEVKE'}, 'id': '4O8BcB7h', 'type': 'tool_call'}]
# <class 'list'>
# 2

# %%
fetch_transcript_tool_output = tool_mapping[tool_calls_2[0]['name']].invoke(tool_calls_2[0]['args'])
fetch_transcript_tool_output
# Out:
# {'title': 'The Ultimate PARIS Travel Vlog 🇫🇷',
#  'views': 1141171,
#  'duration': 4597,
#  'channel': 'Passenger Paramvir',
#  'likes': 26536,
#  'comments': 1500,
#  'chapters': [{'start_time': 0, 'title': 'Intro', 'end_time': 197},
#   {'start_time': 197, 'title': 'Eiffel Tower', 'end_time': 446},
#   {'start_time': 446,
#    'title': 'Arc de Triomphe/Champs-Élysées',
#    'end_time': 714},
#   {'start_time': 714, 'title': 'Galeries Lafayette', 'end_time': 898},
#   {'start_time': 898, 'title': 'Palais Garnier', 'end_time': 968},
#   {'start_time': 968,
#    'title': 'Place de la Concorde/Tuileries Garden',
#    'end_time': 1234},
#   {'start_time': 1234, 'title': 'Louvre', 'end_time': 1443},
#   {'start_time': 1443, 'title': 'Saint-Germain-des-Prés', 'end_time': 1700},
#   {'start_time': 1700, 'title': 'Latin Quarter', 'end_time': 2174},
#   {'start_time': 2174, 'title': 'Luxembourg Garden', 'end_time': 2316},
#   {'start_time': 2316, 'title': 'Notre Dame Cathedral', 'end_time': 2635},
#   {'start_time': 2635, 'title': 'Hotel de ville', 'end_time': 2695},
#   {'start_time': 2695, 'title': 'Le Marais', 'end_time': 2940},
#   {'start_time': 2940, 'title': 'Châtelet', 'end_time': 2980},
#   {'start_time': 2980, 'title': 'Day 2', 'end_time': 3236},
#   {'start_time': 3236, 'title': 'Île de la Cité/Le Marais', 'end_time': 3427},
#   {'start_time': 3427, 'title': 'Quartier Pigalle', 'end_time': 3660},
#   {'start_time': 3660, 'title': 'Montmartre', 'end_time': 4458},
#   {'start_time': 4458, 'title': 'La Défense and Bloopers', 'end_time': 4597}]}

# %%
messages.append(ToolMessage(content = fetch_transcript_tool_output, tool_call_id = tool_calls_2[0]['id']))

# %%
summary = llm_with_tools.invoke(messages)

# %%
summary
# Out:
# AIMessage(content=[], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fa9c1-2a01-7e50-b14e-d492e2921e05-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1480, 'output_tokens': 0, 'total_tokens': 1480, 'input_token_details': {'cache_read': 0}})

# %%
# Define the processing steps
def execute_tool(tool_call):
    """Execute single tool call and return ToolMessage"""
    try:
        result = tool_mapping[tool_call["name"]].invoke(tool_call["args"])
        return ToolMessage(
            content=str(result),
            tool_call_id=tool_call["id"]
        )
    except Exception as e:
        return ToolMessage(
            content=f"Error: {str(e)}",
            tool_call_id=tool_call["id"]
        )

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# %%
from langchain_core.messages import HumanMessage

def run_agent(query, max_steps=8):
    messages = [HumanMessage(content=query)]

    for step in range(max_steps):

        response = llm_with_tools.invoke(messages)
        messages.append(response)

        # Finished?
        if not response.tool_calls:
            return response.content

        # Execute tools
        for tool_call in response.tool_calls:

            tool_message = execute_tool(tool_call)
            messages.append(tool_message)

        # ⭐ NEW: Ask the model to finish after tool execution
        messages.append(
            HumanMessage(
                content="""
You have already received the tool outputs.

If you have enough information, DO NOT call any more tools.
Provide the final answer to the user.

Only call another tool if absolutely necessary.
"""
            )
        )

    return "Maximum steps reached."

# %%
result = run_agent(
    "Summarize this YouTube video: https://youtu.be/8x6vXibEVKE?si=vzjTGEdMk8fgoCtL"
)

print(result)
# Out:
# [{'type': 'text', 'text': 'Here is a summary of **"The Ultimate PARIS Travel Vlog 🇫🇷"** by **Passenger Paramvir**:\n\n---\n\n### **Overview**\nIn this travel vlog, Paramvir explores Paris over two days to provide a practical guide to the city’s top landmarks, neighborhoods, local food scenes, and transit tips—while offering comparisons to **Montreal**, another major French-speaking city he previously visited.\n\n---\n\n### **Day 1: Iconic Landmarks, Shopping & Food Exploration**\n\n1. **Eiffel Tower (7th Arrondissement):**\n   * *Tips & Trivia:* Recommends viewing Paris from the **second floor** rather than the summit due to clearer views and shorter elevator lines. Notes how the tower temporarily expands by up to 6 inches in extreme summer heat due to thermal expansion.\n2. **Arc de Triomphe & Champs-Élysées (8th Arrondissement):**\n   * Highlights Napoleon’s colossal stone arch at Place Charles de Gaulle and explores the 2 km Champs-Élysées avenue, showcasing Haussmann-style architectural facades, luxury stores, and outdoor cafes.\n3. **Galeries Lafayette & Palais Garnier:**\n   * Visits the iconic department store to see its 43-meter stained-glass dome and takes the elevator to the free rooftop terrace for a panoramic view of the skyline. Right next door is the Neo-Baroque Palais Garnier Opera House.\n4. **Place de la Concorde & Tuileries Garden:**\n   * Features the giant Egyptian Obelisk, Tuileries Garden’s green chairs, and a summer setup displaying the Paris Olympics helium balloon cauldron.\n5. **Louvre Museum:**\n   * Focuses on the recognizable glass pyramid entrance. Notes that with 35,000 displayed artworks (including the Mona Lisa), seeing every piece for just 30 seconds would take over 12 days.\n6. **Saint-Germain-des-Prés & Latin Quarter (5th & 6th Arrondissements):**\n   * Highlights these central, historic neighborhoods as ideal places to stay. Visits the **Panthéon**, **Luxembourg Garden**, and lively student-filled cobblestone streets near Sorbonne University.\n7. **Croissant & Pastry Hunt:**\n   * Tries pastries at award-winning bakeries (*La Maison d\'Isabelle*, *Boulangerie Moderne*, and *Guyot Ferreira*). Declares **Boulangerie Moderne’s** butter croissant as his personal favorite for its flakiness and crispiness.\n8. **Notre-Dame Cathedral & Seine River:**\n   * Navigates the queue to tour the newly restored, massive interior of Notre-Dame on Île de la Cité. Recommends taking a Seine River cruise for evening views of the sparkling Eiffel Tower.\n9. **Le Marais & Châtelet:**\n   * Explores Le Marais, known for trendy cafes, vibrant nightlife, and organic Lebanese Ashta ice cream at *Bachir*.\n\n---\n\n### **Day 2: Nightlife, Montmartre & City Limits**\n\n1. **Café Culture (La Caféothèque):**\n   * Enjoys coffee near the Seine while pointing out local riverside dining docked on barges.\n2. **Pigalle & Moulin Rouge (18th Arrondissement):**\n   * Walks through the historic red-light and nightlife district of Pigalle, pointing out the iconic red windmill of the **Moulin Rouge** cabaret theater.\n3. **Montmartre & Sacré-Cœur Basilica:**\n   * Climbs the steps to Sacré-Cœur for sunset views over Paris. Highlights the bohemian atmosphere of Montmartre, cobblestone lanes, street performers, and painters at **Place du Tertre**.\n4. **La Défense:**\n   * Concludes by mentioning how Paris preserved its core historical identity by placing modern skyscrapers and high-rises outside the central city in the business district of La Défense.\n\n---\n\n### **Key Travel Tips & Paris vs. Montreal Comparison**\n\n* **Transportation:** Paper tickets are obsolete in Paris; travelers can use the **IDF Mobility** or **Bonjour RATP** app with NFC/Navigo pass. Single transit tickets cost ~€2.55 (slightly more expensive than Montreal\'s metro).\n* **Where to Stay:** \n  * **Recommended:** *Saint-Germain-des-Prés, Latin Quarter, Le Marais, or Montmartre* (central, lively, aesthetic).\n  * **Avoid:** Staying right next to the Eiffel T ...

# %%
initial_setup = RunnablePassthrough.assign(
    messages=lambda x: [HumanMessage(content=x["query"])]
)

# %%
first_llm_call = RunnablePassthrough.assign(
    ai_response=lambda x: llm_with_tools.invoke(x["messages"])
)

# %%
first_tool_processing = RunnablePassthrough.assign(
    tool_messages=lambda x: [
        execute_tool(tc) for tc in x["ai_response"].tool_calls
    ]
).assign(
    messages=lambda x: x["messages"] + [x["ai_response"]] + x["tool_messages"]
)

# %%
second_llm_call = RunnablePassthrough.assign(
    ai_response2=lambda x: llm_with_tools.invoke(x["messages"])
)

# %%
second_tool_processing = RunnablePassthrough.assign(
    tool_messages2=lambda x: [
        execute_tool(tc) for tc in x["ai_response2"].tool_calls
    ]
).assign(
    messages=lambda x: x["messages"] + [x["ai_response2"]] + x["tool_messages2"]
)

# %%
final_summary = RunnablePassthrough.assign(
    summary=lambda x: llm_with_tools.invoke(x["messages"]).content
) | RunnableLambda(lambda x: x["summary"])

# %%
chain = (
    initial_setup
    | first_llm_call
    | first_tool_processing
    | second_llm_call
    | second_tool_processing
    | final_summary
)

# %%
query = "I want to summarize this YouTube video in English: https://youtu.be/8x6vXibEVKE?si=vzjTGEdMk8fgoCtL"

result = run_agent(query)

print("Video Summary:\n")
print(result)
# Out:
# Video Summary:
#
# [{'type': 'text', 'text': 'Here is a comprehensive summary of **"The Ultimate PARIS Travel Vlog"** by **Passenger Paramvir**:\n\n---\n\n### **Executive Summary**\nIn this 76-minute travel vlog, Indian travel creator **Paramvir** delivers a practical guide to exploring Paris. Having recently visited **Montreal** (the world’s second-largest French-speaking city), he uses this trip to compare both cities in terms of transport, cost, food, ambiance, safety, and culture. \n\nRather than focusing purely on museums or high-end shopping, the video acts as an honest guide highlighting **the best neighborhoods to stay, local food experiences, major landmarks, budget tips, and areas to avoid.**\n\n---\n\n### **Key Highlights & Video Structure**\n\n#### **1. Iconic Landmarks**\n* **Eiffel Tower (7th Arrondissement):** Standing at 330m, it was originally disliked by locals and saved because it functioned as a radio antenna. Paramvir recommends visiting the **2nd floor** instead of the top, as the queue is shorter and the views are clearer. He also notes how heat causes the iron tower to expand slightly in summer.\n* **Arc de Triomphe & Champs-Élysées (8th Arrondissement):** Built by Napoleon in 1806 to celebrate military victories. The 2 km Champs-Élysées avenue features flagship luxury stores, fashion inspiration, and hosts major events like Tour de France and military parades.\n* **Galeries Lafayette & Palais Garnier:**\n  * **Galeries Lafayette:** Famous for its 43m glass dome, glass walkway, and **free rooftop terrace** offering panoramic views of the Paris skyline and Eiffel Tower.\n  * **Palais Garnier:** Neo-Baroque Opera House adorned with gold leaf, theatrical sculptures, and multi-colored marble.\n* **Place de la Concorde & Tuileries Garden:** \n  * Features the giant Egyptian Obelisk and iconic green lawn chairs for public relaxation.\n  * Paramvir highlights the **2024 Olympic Cauldron helium balloon** installed during summer seasons.\n* **The Louvre Museum:** Known for its glass pyramid entrance and 35,000+ displayed artworks. Paramvir notes that viewing each piece for just 30 seconds would take **12 full days**, suggesting **Musée d\'Orsay** as an alternative for art lovers.\n* **Notre-Dame Cathedral & Île de la Cité:** Situated on the historic island where Paris originated. Despite massive queues and ongoing post-fire restoration, Paramvir praises its scale and historic grandeur.\n\n---\n\n#### **2. Neighborhood Guide & Accommodation Advice**\n\n| Neighborhood | Vibe & Features | Accommodation Advice |\n| :--- | :--- | :--- |\n| **Saint-Germain-des-Prés (6th)** | Elegant, classic Parisian architecture, quiet streets, cozy bistros. | **Best area to stay** (if budget permits); very central and quiet at night. |\n| **Latin Quarter (5th)** | Youthful, lively area around Sorbonne University & the Pantheon; medieval cobblestone lanes. | **Great for budget travelers**; affordable cafes and vibrant nightlife. |\n| **Le Marais (3rd/4th)** | Trendy, historic, filled with viral food spots, cafes, and Paris\'s most LGBT-friendly district. | **Highly recommended** for a central, vibrant, trendy experience. |\n| **Montmartre & Pigalle (9th/18th)** | Hilltop village with Sacré-Cœur Basilica, panoramic views, street painters, and Moulin Rouge cabaret in Pigalle. | **Great for atmosphere**, but avoid if you dislike steep stairs/climbing. |\n| **Gare du Nord / Gare de l\'Est** | Dodgy, dirty streets with high immigrant market density and trash accumulation. | **Avoid staying here** despite transit convenience. |\n| **Eiffel Tower Area** | Tourist-heavy landmark zone. | **Avoid staying here**; lacks authentic neighborhood charm, local food, and night activity. |\n\n---\n\n#### **3. Food & Bakery Guide**\nParamvir focuses heavily on testing famous Parisian bakeries (*boulangeries*) and street food:\n* **Croissant Face-off:**\n  * *La Maison d\'Isabelle* (Award-winning bakery): Good, but sold out quickly.\n  * *Boulangerie Moderne* (Featured in  ...

# %%
result = run_agent(
    'Search YouTube for "Top 3 videos of Commonweath Games 2026 for team India" and return the metadata for the first three results.'
)

print(result)
# Out:
# [{'type': 'text', 'text': 'Here are the metadata for the first three YouTube search results for **"Top 3 videos of Commonwealth Games 2026 for team India"**:\n\n---\n\n### **1. Video Result 1**\n* **Title:** Commonwealth Games 2026 : जानिए CWG 2026 में India के Day 3(25 July) के Full Results |\n* **URL:** [https://youtu.be/wPCpQ2B-wVY](https://youtu.be/wPCpQ2B-wVY)\n* **Channel:** Aapki Baithak\n* **Views:** 17,346\n* **Likes:** 430\n* **Comments:** 23\n* **Duration:** 5 minutes 10 seconds (310 seconds)\n\n---\n\n### **2. Video Result 2**\n* **Title:** Commonwealth Games 2026, Day 5 | TeamIndia | CWG 2026\n* **URL:** [https://youtu.be/iriI5LZN1XU](https://youtu.be/iriI5LZN1XU)\n* **Channel:** Prasar Bharati Sports\n* **Views:** 15,895\n* **Likes:** 142\n* **Comments:** 6\n* **Duration:** 19 minutes 15 seconds (1,155 seconds)\n\n---\n\n### **3. Video Result 3**\n* **Title:** Commonwealth Games 2026: India\'s Medal Tally Rises To Ten | WION World DNA\n* **URL:** [https://youtu.be/SGMudXIfgzo](https://youtu.be/SGMudXIfgzo)\n* **Channel:** WION\n* **Views:** 9,528\n* **Likes:** 73\n* **Comments:** 24\n* **Duration:** 2 minutes 55 seconds (175 seconds)', 'extras': {'signature': 'EqEBCp4BARFNMg9YNxM40DYNC1UdoV0WiaXSGAZHIO4UBesZ61nkjq46rEoaL5gQPbWiY7131PcEmMntfLMImkzClY8xJ/Sg05HVUz2zr3a4Be9EWK/fLs+JhkY63YidncDXLrvsB+soRlKbMQXHbgt608jEIDHIspfxquOaTipCzB0Yg6jZONEzhy/Az+Q/HuO3+SgCsRQ1zNs9HjqJFMVlGFg='}}]

# %%
result
# Out:
# [{'type': 'text',
#   'text': 'Here are the metadata for the first three YouTube search results for **"Top 3 videos of Commonwealth Games 2026 for team India"**:\n\n---\n\n### **1. Video Result 1**\n* **Title:** Commonwealth Games 2026 : जानिए CWG 2026 में India के Day 3(25 July) के Full Results |\n* **URL:** [https://youtu.be/wPCpQ2B-wVY](https://youtu.be/wPCpQ2B-wVY)\n* **Channel:** Aapki Baithak\n* **Views:** 17,346\n* **Likes:** 430\n* **Comments:** 23\n* **Duration:** 5 minutes 10 seconds (310 seconds)\n\n---\n\n### **2. Video Result 2**\n* **Title:** Commonwealth Games 2026, Day 5 | TeamIndia | CWG 2026\n* **URL:** [https://youtu.be/iriI5LZN1XU](https://youtu.be/iriI5LZN1XU)\n* **Channel:** Prasar Bharati Sports\n* **Views:** 15,895\n* **Likes:** 142\n* **Comments:** 6\n* **Duration:** 19 minutes 15 seconds (1,155 seconds)\n\n---\n\n### **3. Video Result 3**\n* **Title:** Commonwealth Games 2026: India\'s Medal Tally Rises To Ten | WION World DNA\n* **URL:** [https://youtu.be/SGMudXIfgzo](https://youtu.be/SGMudXIfgzo)\n* **Channel:** WION\n* **Views:** 9,528\n* **Likes:** 73\n* **Comments:** 24\n* **Duration:** 2 minutes 55 seconds (175 seconds)',
#   'extras': {'signature': 'EqEBCp4BARFNMg9YNxM40DYNC1UdoV0WiaXSGAZHIO4UBesZ61nkjq46rEoaL5gQPbWiY7131PcEmMntfLMImkzClY8xJ/Sg05HVUz2zr3a4Be9EWK/fLs+JhkY63YidncDXLrvsB+soRlKbMQXHbgt608jEIDHIspfxquOaTipCzB0Yg6jZONEzhy/Az+Q/HuO3+SgCsRQ1zNs9HjqJFMVlGFg='}}]

# %%
from langchain_core.runnables import RunnableBranch, RunnableLambda
from langchain_core.messages import HumanMessage, ToolMessage
import json

def execute_tool(tool_call):
    """Execute single tool call and return ToolMessage"""
    try:
        result = tool_mapping[tool_call["name"]].invoke(tool_call["args"])
        content = json.dumps(result) if isinstance(result, (dict, list)) else str(result)
    except Exception as e:
        content = f"Error: {str(e)}"

    return ToolMessage(
        content=content,
        tool_call_id=tool_call["id"]
    )

# %%
def process_tool_calls(messages):
    """Recursive tool call processor"""
    last_message = messages[-1]

    # Execute all tool calls in parallel
    tool_messages = [
        execute_tool(tc)
        for tc in getattr(last_message, 'tool_calls', [])
    ]

    # Add tool responses to message history
    updated_messages = messages + tool_messages

    # Get next LLM response
    next_ai_response = llm_with_tools.invoke(updated_messages)

    return updated_messages + [next_ai_response]

# %%
def should_continue(messages):
    """Check if you need another iteration"""
    last_message = messages[-1]
    return bool(getattr(last_message, 'tool_calls', None))

# %%
def _recursive_chain(messages):
    """Recursively process tool calls until completion"""
    if should_continue(messages):
        new_messages = process_tool_calls(messages)
        return _recursive_chain(new_messages)
    return messages

recursive_chain = RunnableLambda(_recursive_chain)

# %%
universal_chain = (
    RunnableLambda(lambda x: [HumanMessage(content=x["query"])])
    | RunnableLambda(lambda messages: messages + [llm_with_tools.invoke(messages)])
    | recursive_chain
)

# %%
query_us = {"query": "Show top 3 CJP protest videos in India with metadata and thumbnails"}

try:
    response = universal_chain.invoke(query_us)
    print("\nCJP Trending Videos:\n", response[-1])
except Exception as e:
    print("Non-critical network error while fetching CJP trending videos:", e)
# Out:
# CJP Trending Videos:
#  content=[{'type': 'text', 'text': "Here are the top 3 CJP protest videos in India, along with their metadata and thumbnails:\n\n---\n\n### 1. India's education minister steps down amid CJP protests\n* **Channel:** DW News\n* **Views:** 171,997+\n* **Likes:** 4,435\n* **Comments:** 778\n* **Duration:** 3 minutes 55 seconds (235s)\n* **Watch Link:** [YouTube Link](https://www.youtube.com/watch?v=r3r1LhRxHvc)\n\n![Thumbnail](https://i.ytimg.com/vi/r3r1LhRxHvc/maxresdefault.jpg)\n\n---\n\n### 2. What's behind the protests and cockroaches in India?\n* **Channel:** ABC News (Australia)\n* **Views:** 77,263+\n* **Likes:** 4,476\n* **Duration:** 1 minute 37 seconds (97s)\n* **Watch Link:** [YouTube Link](https://www.youtube.com/watch?v=CtSl4NRjVF8)\n\n![Thumbnail](https://i.ytimg.com/vi/CtSl4NRjVF8/maxresdefault.jpg)\n\n---\n\n### 3. CJP Protest Crackdown: SC orders Immediate Release of Students Without Criminal Record\n* **Channel:** WION\n* **Views:** 3,957+\n* **Likes:** 27\n* **Comments:** 7\n* **Duration:** 1 minute 31 seconds (91s)\n* **Watch Link:** [YouTube Link](https://www.youtube.com/watch?v=VJ32zaRN88M)\n\n![Thumbnail](https://i.ytimg.com/vi/VJ32zaRN88M/maxresdefault.jpg)", 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019fa9c3-7d16-7463-a724-73bfa0d61f1f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8825, 'output_tokens': 941, 'total_tokens': 9766, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 519}}
